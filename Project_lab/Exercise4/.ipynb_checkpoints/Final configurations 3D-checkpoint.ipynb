# %% [markdown]
# ## Plot delle configurazioni finali di 3 simulazioni
#
# ### Configurazione iniziale fcc

# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x, y, z = np.loadtxt("config.fcc", usecols= (0, 1, 2),  unpack = True) 
d = len(x)
ax.plot3D(x, y, z, linewidth = 0.0, marker = '.')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ### Configurazione finale del gas $ ( T = 1.2 ,  \rho = 0.05 )$

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x, y, z = np.loadtxt("configGas.final", usecols= (0, 1, 2),  unpack = True) 
d = len(x)
ax.plot3D(x, y, z, linewidth = 0.0, marker = '.')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ### Configurazionefinale del liquido $( T = 1.9, \rho = 0.8)$

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x, y, z = np.loadtxt("configLiquid.final", usecols= (0, 1, 2),  unpack = True) 
d = len(x)
ax.plot3D(x, y, z, linewidth = 0.0, marker = '.')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ### Configurazione finale solido $( T = 1.4, \rho = 1.1)$

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x, y, z = np.loadtxt("configSolid.final", usecols= (0, 1, 2),  unpack = True) 
d = len(x)
ax.plot3D(x, y, z, linewidth = 0.0, marker = '.')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
