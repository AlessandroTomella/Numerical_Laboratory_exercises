# %% [markdown]
# # Prima parte: stima dell'integrale

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

def error(AV1,AV2,n):  # Function for statistical uncertainty estimation
    if n==0:
        return 0
    else:
        return math.sqrt((AV1[n] - AV2[n])/n)

x, p_ave, p_ave2 = np.loadtxt("values2.out", usecols=(0, 1, 2), delimiter=' ', unpack='true')
N = len(x)
n = np.arange(N)
e = np.zeros(N)

for i in range(N):
    e[i] = error(p_ave, p_ave2,i)

plt.errorbar(n, x-0.5, e);
plt.xlabel('#blocks')
plt.ylabel('<r>-1/2')
plt.grid(True)
plt.show()

# %%
x, p_ave, p_ave2 = np.loadtxt("values3.out", usecols=(0, 1, 2), delimiter=' ', unpack='true')
N = len(x)
n = np.arange(N)
e = np.zeros(N)

for i in range(N):
    e[i] = error(p_ave, p_ave2,i)

plt.errorbar(n, x-1/12, e);
plt.xlabel('#blocks')
plt.ylabel('<(r-0.5)^2>-1/12')
plt.grid(True)
plt.show()

# %%
INT = 100
CHI_POINTS=10000
a1 = np.zeros(N)
a2 = np.zeros(N)

chi_test = np.loadtxt("chi2_values.out")

#print(sum(chi_test)/(CHI_POINTS/INT))

for k in range(N):
    a1[k] = listsum(chi_test, k)
    a2[k] = listsum2(chi_test, k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2eadd7c68006> in <module>
#       9
#      10 for k in range(N):
# ---> 11     a1[k] = listsum(chi_test, k)
#      12     a2[k] = listsum2(chi_test, k)
#
# NameError: name 'listsum' is not defined
